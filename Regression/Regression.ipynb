# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ### Create your one datset using scikit learn

# %%
from sklearn.datasets import make_regression
X, Y = make_regression(n_features=30, n_samples=10000, noise=10, random_state=42)

# %%
X
# Out:
# array([[ 1.20260394,  0.53941732,  1.7208958 , ...,  1.23385116,
#          0.14625334, -1.52026351],
#        [ 1.12861518,  1.18765629,  0.19037335, ...,  0.00919487,
#          0.33287077, -1.10080199],
#        [-0.33343479, -1.10421512,  0.50152123, ...,  0.04086189,
#          0.9478043 , -0.33589088],
#        ...,
#        [ 0.23023411,  1.3728802 ,  2.03195102, ...,  1.32541224,
#          1.51237514, -0.99261504],
#        [ 0.364961  ,  0.87006773, -0.75427585, ...,  0.15041891,
#          0.4535343 , -0.24415664],
#        [ 0.00967792, -0.31528608, -0.77882011, ..., -2.72258148,
#         -0.32157746,  0.1505211 ]])

# %%
X.shape
# Out:
# (10000, 30)

# %%
Y.shape
# Out:
# (10000,)

# %%
cols = [f'x{i}' for i in range(30)]
cols
# Out:
# ['x0',
#  'x1',
#  'x2',
#  'x3',
#  'x4',
#  'x5',
#  'x6',
#  'x7',
#  'x8',
#  'x9',
#  'x10',
#  'x11',
#  'x12',
#  'x13',
#  'x14',
#  'x15',
#  'x16',
#  'x17',
#  'x18',
#  'x19',
#  'x20',
#  'x21',
#  'x22',
#  'x23',
#  'x24',
#  'x25',
#  'x26',
#  'x27',
#  'x28',
#  'x29']

# %%
import pandas as pd
X = pd.DataFrame(X)
X.columns = cols
X
# Out:
#             x0        x1        x2        x3        x4        x5        x6  \
# 0     1.202604  0.539417  1.720896  0.043760 -0.848163 -0.399068 -0.262965
# 1     1.128615  1.187656  0.190373  0.701755  0.379554  1.024657 -0.423376
# 2    -0.333435 -1.104215  0.501521  0.567752  0.979204 -0.724839 -0.676388
# 3    -0.110892 -0.338529 -1.335493 -1.006371  0.113546  1.324523  0.583362
# 4     0.666259 -0.103303 -0.870944  0.037781  0.435394  0.375820 -0.503499
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.236521  0.165004 -0.459711  1.648568 -1.313626 -0.169812  1.727511
# 9996  0.794550 -0.199673  0.240345  1.218683  0.127586 -1.639118  0.481503
# 9997  0.230234  1.372880  2.031951 -0.264717  1.076618 -1.364529  2.216187
# 9998  0.364961  0.870068 -0.754276  1.633432  1.187030  0.321357  0.597400
# 9999  0.009678 -0.315286 -0.778820 -2.051908 -0.478765 -1.116431  0.617345
#
#             x7        x8        x9  ...       x20       x21       x22  \
# 0    -1.153374  1.841415  0.482886  ...  1.230686 -0.752198 -0.776306
# 1    -0.941577 -0.983186  1.288450  ... -0.774494 -1.058985 -0.404962
# 2     1.508184  0.954942  0.907828  ... -0.189116  0.251156 -0.661080
# 3     0.377346 -0.947948  0.124305  ... -1.411303 -1.043604  1.841754
# 4     1.680087 -0.302130 -2.030275  ... -1.740227  2.323069 -1.021984
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995 -0.351814 -1.385680 -0.152501  ... -1.436373 -0.177183 -1.871847
# 9996  0.049615  0.887197  0.413178  ... -1.601121  1.897456  1.248198
# 9997  0.846413  1.101675 -1.592132  ...  1.251438  2.301518  1.206735
# 9998 -1.227608  0.328762  0.421921  ...  0.302635  1.105526 -0.057619
# 9999 -0.279664  0.566136  1.461384  ...  0.655582 -0.343057  1.053986
#
#            x23       x24       x25       x26       x27       x28       x29
# 0    -0.665028 -0.134179 -0.126667  0.126299  1.233851  0.146253 -1.520264
# 1    -0.566263  1.946349 -0.360434  0.038952  0.009195  0.332871 -1.100802
# 2    -0.242712  2.057644 -1.097065  1.436948  0.040862  0.947804 -0.335891
# 3    -0.262621 -0.247876 -2.171152 -1.256592 -1.117782  0.356409 -1.075123
# 4     1.131287  1.579717  0.511236  0.779930 -0.895705  1.096482 -1.775758
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.983345 -0.519716  0.538120  0.314011  0.473811 -1.155886  1.419856
# 9996 -1.407733  0.627111 -0.323075 -0.119273 -0.262647  0.023143 -1.419576
# 9997  0.245901 -0.849317  0.386093  0.003372  1.325412  1.512375 -0.992615
# 9998 -1.143005  0.638730  0.495682  0.701173  0.150419  0.453534 -0.244157
# 9999 -0.876275 -1.492896 -0.691464 -0.113189 -2.722581 -0.321577  0.150521
#
# [10000 rows x 30 columns]

# %%
Y = pd.DataFrame(Y)
Y.columns = ['Y']
Y
# Out:
#                Y
# 0     237.636313
# 1     -36.095039
# 2      45.865613
# 3     101.563535
# 4     -81.665319
# ...          ...
# 9995 -128.934674
# 9996   73.918331
# 9997  430.788112
# 9998  220.155677
# 9999  -36.508598
#
# [10000 rows x 1 columns]

# %% [markdown]
# ### Create preprocessing pipeline for X

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = Pipeline(steps=[('impute', SimpleImputer(strategy='median')),
                           ('scaler', StandardScaler())])

# %%
X_pre = num_pipe.fit_transform(X)
X_pre
# Out:
# array([[ 1.19026328e+00,  5.31936021e-01,  1.73232296e+00, ...,
#          1.22634724e+00,  1.53860748e-01, -1.52877712e+00],
#        [ 1.11650308e+00,  1.18559352e+00,  1.99093904e-01, ...,
#         -3.09675269e-03,  3.39591275e-01, -1.11031198e+00],
#        [-3.41030389e-01, -1.12543528e+00,  5.10792024e-01, ...,
#          2.86940649e-02,  9.51602322e-01, -3.47217819e-01],
#        ...,
#        [ 2.20897251e-01,  1.37236568e+00,  2.04392826e+00, ...,
#          1.31826627e+00,  1.51349003e+00, -1.00238202e+00],
#        [ 3.55207947e-01,  8.65350287e-01, -7.47225828e-01, ...,
#          1.38679387e-01,  4.59681354e-01, -2.55701475e-01],
#        [ 1.02238497e-03, -3.29911705e-01, -7.71813493e-01, ...,
#         -2.74555278e+00, -3.11746673e-01,  1.38038752e-01]])

# %%
cols = num_pipe.get_feature_names_out()
cols
# Out:
# array(['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10',
#        'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19',
#        'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28',
#        'x29'], dtype=object)

# %%
X_pre = pd.DataFrame(X_pre, columns=cols)
X_pre.head()
# Out:
#          x0        x1        x2        x3        x4        x5        x6  \
# 0  1.190263  0.531936  1.732323  0.035179 -0.856047 -0.393790 -0.262125
# 1  1.116503  1.185594  0.199094  0.692311  0.366257  1.033597 -0.423723
# 2 -0.341030 -1.125435  0.510792  0.558484  0.963264 -0.720399 -0.678607
# 3 -0.119175 -0.353349 -1.329470 -1.013575  0.101422  1.334233  0.590465
# 4  0.655575 -0.116156 -0.864100  0.029207  0.421851  0.383091 -0.504439
#
#          x7        x8        x9  ...       x20       x21       x22       x23  \
# 0 -1.161383  1.868193  0.484793  ...  1.238474 -0.742749 -0.775551 -0.656460
# 1 -0.946804 -0.985350  1.292009  ... -0.782919 -1.043928 -0.405869 -0.557010
# 2  1.535127  0.972636  0.910607  ... -0.192808  0.242264 -0.660841 -0.231215
# 3  0.389439 -0.949751  0.125478  ... -1.424878 -1.028828  1.830792 -0.251262
# 4  1.709288 -0.297316 -2.033521  ... -1.756460  2.276302 -1.020129  1.152316
#
#         x24       x25       x26       x27       x28       x29
# 0 -0.120550 -0.105212  0.130520  1.226347  0.153861 -1.528777
# 1  1.959455 -0.339913  0.042404 -0.003097  0.339591 -1.110312
# 2  2.070721 -1.079486  1.452704  0.028694  0.951602 -0.347218
# 3 -0.234218 -2.157864 -1.264541 -1.134479  0.363017 -1.084694
# 4  1.592915  0.535239  0.789904 -0.911534  1.099573 -1.783665
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Train test split

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X_pre, Y, test_size=0.2, random_state=42)

# %%
xtrain.shape
# Out:
# (8000, 30)

# %%
xtest.shape
# Out:
# (2000, 30)

# %%
xtrain.head()
# Out:
#             x0        x1        x2        x3        x4        x5        x6  \
# 9254  0.967186  1.328597 -0.158799 -0.513092 -0.546330  0.496599  1.007340
# 1561  0.948147  0.196019  1.078674  0.400995 -0.393806 -0.271407  0.339533
# 1670  0.564531  1.263594  0.289266 -1.141822 -0.333383  0.760849 -0.994772
# 6087  2.252564 -0.442793  0.123201 -0.295946  1.328350 -0.165132 -0.677119
# 6669 -0.519707 -0.383423 -1.624628 -1.222178 -1.211544 -0.342929 -2.315833
#
#             x7        x8        x9  ...       x20       x21       x22  \
# 9254  1.592817  1.579324 -0.616374  ... -0.106186 -0.390775 -0.293840
# 1561  0.135978 -1.549146  0.679960  ... -0.286113  0.515112 -0.290717
# 1670  0.900410 -0.269388  0.773494  ...  0.231544 -0.159887 -0.765145
# 6087  0.771689 -0.753630 -1.231975  ... -0.012095 -1.362518  1.449863
# 6669  0.555577  0.338412  0.475314  ... -0.229627  1.746033  0.986339
#
#            x23       x24       x25       x26       x27       x28       x29
# 9254 -0.443878  1.402890  1.544408  1.285420 -0.107279  0.030216  0.613977
# 1561 -0.900252 -1.311642 -1.092441  0.075198 -1.024891  1.189724  0.749394
# 1670 -1.937997 -0.938283 -0.937716 -0.057406 -0.781819  0.781652  0.297887
# 6087 -0.028918  0.714926  0.779378 -0.369218  0.165956  0.748312  1.038317
# 6669 -0.189628  0.896746  0.111370 -1.680810  0.222902  1.295827 -1.087529
#
# [5 rows x 30 columns]

# %%
xtest.head()
# Out:
#             x0        x1        x2        x3        x4        x5        x6  \
# 6252  0.116859  1.372954  0.565213 -0.352506  1.069433  0.317491  0.989413
# 4684  0.508333  1.508077  0.506831  0.274184 -0.671324 -0.225367  1.789933
# 1731 -0.047478  1.647545  0.212329 -1.123403 -0.221378  1.201875  0.018055
# 4742 -0.608950 -2.089229 -0.773764 -1.378191 -1.129480 -0.907056  1.609373
# 4521 -0.486161  0.002415  0.111972  0.519668  1.536226 -1.565969  0.833691
#
#             x7        x8        x9  ...       x20       x21       x22  \
# 6252  0.882498  0.984145  0.837112  ...  0.280053 -0.210325  0.327190
# 4684  0.059766  0.556868 -0.401001  ...  1.219960 -1.185854  0.064940
# 1731 -0.354640  0.121304  0.455258  ...  0.224456  0.319017 -1.002326
# 4742  0.473357  2.203663  0.722274  ... -0.970691 -0.877047  1.343510
# 4521 -0.689726  0.093792  0.665543  ...  0.354167 -2.020082 -0.995287
#
#            x23       x24       x25       x26       x27       x28       x29
# 6252 -1.356206 -1.149499  0.989122 -1.398435  0.779081  1.033443 -0.971218
# 4684 -0.081423  1.904180  0.724515  0.652131  1.464160  0.542158  1.198302
# 1731 -1.247122 -1.126300  0.108956 -1.725228 -0.759353  0.901466 -1.474057
# 4742  0.637397 -0.590092 -1.079938  0.759705  0.033535 -0.464185  1.056706
# 4521  1.024886  0.099420 -2.667209  0.375062  1.521895 -1.206615  0.145322
#
# [5 rows x 30 columns]

# %%
ytrain.head()
# Out:
#                Y
# 9254  -12.438539
# 1561 -170.371791
# 1670  -45.466291
# 6087  301.429245
# 6669   44.699217

# %%
ytest.head()
# Out:
#                Y
# 6252  160.109185
# 4684  379.549189
# 1731 -162.120660
# 4742  -32.375767
# 4521 -106.253689

# %% [markdown]
# ### Create a Neural network

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# WARNING:tensorflow:From d:\Data Science\Deep Learning github repository\repository\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# initialize a seqyential model
model = Sequential()

# Create Hidden Layer 1
model.add(Dense(units=32, activation='relu', input_dim=xtrain.shape[1]))

# Create Hidden Layer 2
model.add(Dense(units=16, activation='relu'))

# Create Hidden Layer 3
model.add(Dense(units=8, activation='relu'))

# create a output layer
model.add(Dense(units=1, activation='linear'))
# Out:
# WARNING:tensorflow:From d:\Data Science\Deep Learning github repository\repository\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# ### Compile the model

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Out:
# WARNING:tensorflow:From d:\Data Science\Deep Learning github repository\repository\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ### Fit the model

# %%
hist = model.fit(xtrain, ytrain, validation_split=0.2, epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From d:\Data Science\Deep Learning github repository\repository\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From d:\Data Science\Deep Learning github repository\repository\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 200/200 [==============================] - 5s 9ms/step - loss: 34494.7891 - mae: 148.5406 - val_loss: 29896.8984 - val_mae: 136.7442
# Epoch 2/100
# 200/200 [==============================] - 1s 4ms/step - loss: 12295.2188 - mae: 76.0875 - val_loss: 1133.8300 - val_mae: 24.2438
# Epoch 3/100
# 200/200 [==============================] - 1s 4ms/step - loss: 536.4822 - mae: 17.3725 - val_loss: 351.8644 - val_mae: 14.7104
# Epoch 4/100
# 200/200 [==============================] - 1s 6ms/step - loss: 300.8594 - mae: 13.6094 - val_loss: 293.5164 - val_mae: 13.6533
# Epoch 5/100
# 200/200 [==============================] - 1s 5ms/step - loss: 268.6844 - mae: 12.9641 - val_loss: 276.9358 - val_mae: 13.2247
# Epoch 6/100
# 200/200 [==============================] - 1s 4ms/step - loss: 252.3277 - mae: 12.5395 - val_loss: 262.1381 - val_mae: 12.9150
# Epoch 7/100
# 200/200 [==============================] - 1s 4ms/step - loss: 235.8332 - mae: 12.1659 - val_loss: 258.9372 - val_mae: 12.8717
# Epoch 8/100
# 200/200 [==============================] - 1s 4ms/step - loss: 221.3122 - mae: 11.7842 - val_loss: 262.1615 - val_mae: 12.8860
# Epoch 9/100
# 200/200 [==============================] - 1s 4ms/step - loss: 207.5898 - mae: 11.4007 - val_loss: 225.5489 - val_mae: 12.0443
# Epoch 10/100
# 200/200 [==============================] - 1s 5ms/step - loss: 193.7177 - mae: 11.0073 - val_loss: 217.3919 - val_mae: 11.8138
# Epoch 11/100
# 200/200 [==============================] - 1s 4ms/step - loss: 180.5007 - mae: 10.6677 - val_loss: 207.1473 - val_mae: 11.5396
# Epoch 12/100
# 200/200 [==============================] - 1s 4ms/step - loss: 168.5949 - mae: 10.3317 - val_loss: 190.9709 - val_mae: 11.0768
# Epoch 13/100
# 200/200 [==============================] - 1s 4ms/step - loss: 158.0639 - mae: 9.9931 - val_loss: 182.4980 - val_mae: 10.7571
# Epoch 14/100
# 200/200 [==============================] - 1s 5ms/step - loss: 149.7750 - mae: 9.7288 - val_loss: 177.0174 - val_mae: 10.6223
# Epoch 15/100
# 200/200 [==============================] - 1s 5ms/step - loss: 139.5662 - mae: 9.4105 - val_loss: 165.7678 - val_mae: 10.2977
# Epoch 16/100
# 200/200 [==============================] - 1s 4ms/step - loss: 132.9178 - mae: 9.1839 - val_loss: 159.5510 - val_mae: 10.0746
# Epoch 17/100
# 200/200 [==============================] - 1s 4ms/step - loss: 126.3183 - mae: 8.9485 - val_loss: 152.5973 - val_mae: 9.8460
# Epoch 18/100
# 200/200 [==============================] - 1s 5ms/step - loss: 123.3191 - mae: 8.8610 - val_loss: 151.7741 - val_mae: 9.8040
# Epoch 19/100
# 200/200 [==============================] - 1s 4ms/step - loss: 118.6466 - mae: 8.6933 - val_loss: 147.2750 - val_mae: 9.7022
# Epoch 20/100
# 200/200 [==============================] - 1s 4ms/step - loss: 115.5698 - mae: 8.5815 - val_loss: 143.3402 - val_mae: 9.5390
# Epoch 21/100
# 200/200 [==============================] - 1s 4ms/step - loss: 113.4561 - mae: 8.5031 - val_loss: 139.6875 - val_mae: 9.3926
# Epoch 22/100
# 200/200 [==============================] - 1s 4ms/step - loss: 111.0837 - mae: 8.4130 - val_loss: 139.3648 - val_mae: 9.4165
# Epoch 23/100
# 200/200 [==============================] - 1s 5ms/step - loss: 108.8709 - mae: 8.3268 - val_loss: 136.3208 - val_mae: 9.3054
# Epoch 24/100
# 200/200 [==============================] - 1s 4ms/step - loss: 107.7193 - mae: 8.2779 - val_loss: 134.5894 - val_mae: 9.2094
# Epoch 25/100
# 200/200 [==============================] - 1s 4ms/step - loss: 107.3546 - mae: 8.2731 - val_loss: 138.5494 - val_mae: 9.3926
# Epoch 26/100
# 200/200 [==============================] - 1s 5ms/step - loss: 105.8439 - mae: 8.2484 - val_loss: 135.1190 - val_mae: 9.2622
# Epoch 27/100
# 200/200 [==============================] - 1s 5ms/step - loss: 105.0167 - mae: 8.1756 - val_loss: 129.6862 - val_mae: 9.0365
# Epoch 28/100
# 200/200 [==============================] - 1s 4ms/step - loss: 104.0371 - mae: 8.1367 - val_loss: 134.4180 - val_mae: 9.2642
# Epoch 29/100
# 200/200 [==============================] - 1s 5ms/step - loss: 104.0662 - mae: 8.1309 - val_loss: 133.3397 - val_mae: 9.1830
# Epoch 30/100
# 200/200 [==============================] - 1s 5ms/step - loss: 102.3017 - mae: 8.0707 - val_loss: 129.0331 - val_mae: 9.0248
# Epoch 31/100
# 200/200 [==============================] - 1s 5ms/step - loss: 101.6563 - mae: 8.0430 - val_loss: 130.4052 - val_mae: 9.0392
# Epoch 32/100
# 200/200 [==============================] - 1s 5ms/step - loss: 101.7843 - mae: 8.0493 - val_loss: 130.2857 - val_mae: 9.0690
# Epoch 33/100
# 200/200 [==============================] - 1s 5ms/step - loss: 100.4972 - mae: 7.9921 - val_loss: 132.2086 - val_mae: 9.1353
# Epoch 34/100
# 200/200 [==============================] - 1s 4ms/step - loss: 100.7082 - mae: 7.9951 - val_loss: 131.0665 - val_mae: 9.0639
# Epoch 35/100
# 200/200 [==============================] - 1s 4ms/step - loss: 100.2790 - mae: 7.9496 - val_loss: 127.2928 - val_mae: 8.9788
# Epoch 36/100
# 200/200 [==============================] - 1s 5ms/step - loss: 98.8449 - mae: 7.9210 - val_loss: 126.4192 - val_mae: 8.9449
# Epoch 37/100
# 200/200 [==============================] - 1s 4ms/step - loss: 98.5593 - mae: 7.9265 - val_loss: 128.2668 - val_mae: 8.9478
# Epoch 38/100
# 200/200 [==============================] - 1s 4ms/step - loss: 98.8320 - mae: 7.9428 - val_loss: 126.4811 - val_mae: 8.9229
# Epoch 39/100
# 200/200 [==============================] - 1s 5ms/step - loss: 98.8198 - mae: 7.9295 - val_loss: 127.9532 - val_mae: 9.0271
# Epoch 40/100
# 200/200 [==============================] - 1s 5ms/step - loss: 97.4234 - mae: 7.8904 - val_loss: 125.2939 - val_mae: 8.8816
# Epoch 41/100
# 200/200 [==============================] - 1s 5ms/step - loss: 96.4321 - mae: 7.8374 - val_loss: 122.8198 - val_mae: 8.7917
# Epoch 42/100
# 200/200 [==============================] - 1s 5ms/step - loss: 96.8412 - mae: 7.8697 - val_loss: 128.8709 - val_mae: 9.0526
# Epoch 43/100
# 200/200 [==============================] - 1s 5ms/step - loss: 97.6483 - mae: 7.9195 - val_loss: 123.2436 - val_mae: 8.7912
# Epoch 44/100
# 200/200 [==============================] - 1s 5ms/step - loss: 95.7150 - mae: 7.7965 - val_loss: 125.0422 - val_mae: 8.8672
# Epoch 45/100
# 200/200 [==============================] - 1s 4ms/step - loss: 96.3022 - mae: 7.8431 - val_loss: 124.5539 - val_mae: 8.8421
# Epoch 46/100
# 200/200 [==============================] - 1s 4ms/step - loss: 96.6141 - mae: 7.8462 - val_loss: 123.5813 - val_mae: 8.7942
# Epoch 47/100
# 200/200 [==============================] - 1s 4ms/step - loss: 95.5532 - mae: 7.8159 - val_loss: 124.4428 - val_mae: 8.8242
# Epoch 48/100
# 200/200 [==============================] - 1s 4ms/step - loss: 94.5364 - mae: 7.7693 - val_loss: 123.9161 - val_mae: 8.8213
# Epoch 49/100
# 200/200 [==============================] - 1s 5ms/step - loss: 95.6500 - mae: 7.8038 - val_loss: 122.2375 - val_mae: 8.7734
# Epoch 50/100
# 200/200 [==============================] - 1s 5ms/step - loss: 94.5503 - mae: 7.7501 - val_loss: 128.1340 - val_mae: 8.9666
# Epoch 51/100
# 200/200 [==============================] - 1s 4ms/step - loss: 94.7729 - mae: 7.7880 - val_loss: 126.0532 - val_mae: 8.9173
# Epoch 52/100
# 200/200 [==============================] - 1s 5ms/step - loss: 94.1959 - mae: 7.7166 - val_loss: 128.2170 - val_mae: 9.0215
# Epoch 53/100
# 200/200 [==============================] - 1s 4ms/step - loss: 94.6637 - mae: 7.7465 - val_loss: 130.3304 - val_mae: 9.0392
# Epoch 54/100
# 200/200 [==============================] - 1s 4ms/step - loss: 94.9809 - mae: 7.7596 - val_loss: 123.8138 - val_mae: 8.8088
# Epoch 55/100
# 200/200 [==============================] - 1s 4ms/step - loss: 94.2420 - mae: 7.7618 - val_loss: 126.0742 - val_mae: 8.9275
# Epoch 56/100
# 200/200 [==============================] - 1s 5ms/step - loss: 94.7169 - mae: 7.7896 - val_loss: 124.7064 - val_mae: 8.8651
# Epoch 57/100
# 200/200 [==============================] - 1s 5ms/step - loss: 93.2382 - mae: 7.6892 - val_loss: 124.3702 - val_mae: 8.8506
# Epoch 58/100
# 200/200 [==============================] - 1s 4ms/step - loss: 93.9500 - mae: 7.7230 - val_loss: 125.9904 - val_mae: 8.8931
# Epoch 59/100
# 200/200 [==============================] - 1s 4ms/step - loss: 92.8675 - mae: 7.6692 - val_loss: 124.4973 - val_mae: 8.8461
# Epoch 60/100
# 200/200 [==============================] - 1s 5ms/step - loss: 92.1353 - mae: 7.6658 - val_loss: 123.2357 - val_mae: 8.8371
# Epoch 61/100
# 200/200 [==============================] - 1s 5ms/step - loss: 92.7427 - mae: 7.6713 - val_loss: 122.5817 - val_mae: 8.7943
# Epoch 62/100
# 200/200 [==============================] - 1s 5ms/step - loss: 92.3121 - mae: 7.6693 - val_loss: 125.2075 - val_mae: 8.9016
# Epoch 63/100
# 200/200 [==============================] - 1s 5ms/step - loss: 93.2709 - mae: 7.6974 - val_loss: 124.5593 - val_mae: 8.8972
# Epoch 64/100
# 200/200 [==============================] - 1s 4ms/step - loss: 92.8347 - mae: 7.6905 - val_loss: 126.8696 - val_mae: 8.9386
# Epoch 65/100
# 200/200 [==============================] - 1s 5ms/step - loss: 91.0584 - mae: 7.6224 - val_loss: 134.3427 - val_mae: 9.2555
# Epoch 66/100
# 200/200 [==============================] - 1s 5ms/step - loss: 92.7363 - mae: 7.6437 - val_loss: 120.7904 - val_mae: 8.7069
# Epoch 67/100
# 200/200 [==============================] - 1s 5ms/step - loss: 91.9141 - mae: 7.6211 - val_loss: 127.3519 - val_mae: 8.9707
# Epoch 68/100
# 200/200 [==============================] - 1s 5ms/step - loss: 91.3108 - mae: 7.6168 - val_loss: 127.3216 - val_mae: 8.9705
# Epoch 69/100
# 200/200 [==============================] - 1s 5ms/step - loss: 92.8120 - mae: 7.6595 - val_loss: 122.2962 - val_mae: 8.8322
# Epoch 70/100
# 200/200 [==============================] - 1s 5ms/step - loss: 91.5895 - mae: 7.6170 - val_loss: 120.9249 - val_mae: 8.7512
# Epoch 71/100
# 200/200 [==============================] - 1s 5ms/step - loss: 91.5818 - mae: 7.6418 - val_loss: 123.9414 - val_mae: 8.8427
# Epoch 72/100
# 200/200 [==============================] - 1s 5ms/step - loss: 92.7611 - mae: 7.6846 - val_loss: 120.8751 - val_mae: 8.7460
# Epoch 73/100
# 200/200 [==============================] - 1s 5ms/step - loss: 90.9507 - mae: 7.6145 - val_loss: 122.6120 - val_mae: 8.8150
# Epoch 74/100
# 200/200 [==============================] - 1s 4ms/step - loss: 91.1415 - mae: 7.5945 - val_loss: 123.8461 - val_mae: 8.8351
# Epoch 75/100
# 200/200 [==============================] - 1s 4ms/step - loss: 90.9412 - mae: 7.6029 - val_loss: 121.2072 - val_mae: 8.7559
# Epoch 76/100
# 200/200 [==============================] - 1s 4ms/step - loss: 90.4154 - mae: 7.5652 - val_loss: 123.4525 - val_mae: 8.8403
# Epoch 77/100
# 200/200 [==============================] - 1s 4ms/step - loss: 90.6362 - mae: 7.5893 - val_loss: 124.5240 - val_mae: 8.9037
# Epoch 78/100
# 200/200 [==============================] - 1s 5ms/step - loss: 90.4202 - mae: 7.5957 - val_loss: 121.8463 - val_mae: 8.7899
# Epoch 79/100
# 200/200 [==============================] - 1s 4ms/step - loss: 90.6293 - mae: 7.6040 - val_loss: 119.8239 - val_mae: 8.7333
# Epoch 80/100
# 200/200 [==============================] - 1s 4ms/step - loss: 89.7695 - mae: 7.5597 - val_loss: 125.6521 - val_mae: 8.8994
# Epoch 81/100
# 200/200 [==============================] - 1s 4ms/step - loss: 90.3915 - mae: 7.5798 - val_loss: 128.3775 - val_mae: 9.0290
# Epoch 82/100
# 200/200 [==============================] - 1s 4ms/step - loss: 90.1273 - mae: 7.5703 - val_loss: 123.5539 - val_mae: 8.8625
# Epoch 83/100
# 200/200 [==============================] - 1s 4ms/step - loss: 88.7564 - mae: 7.4873 - val_loss: 125.5112 - val_mae: 8.9073
# Epoch 84/100
# 200/200 [==============================] - 1s 4ms/step - loss: 89.9242 - mae: 7.5574 - val_loss: 123.5489 - val_mae: 8.8599
# Epoch 85/100
# 200/200 [==============================] - 1s 5ms/step - loss: 90.4329 - mae: 7.5585 - val_loss: 122.0900 - val_mae: 8.7921
# Epoch 86/100
# 200/200 [==============================] - 1s 4ms/step - loss: 90.6047 - mae: 7.5903 - val_loss: 125.3552 - val_mae: 8.9076
# Epoch 87/100
# 200/200 [==============================] - 1s 4ms/step - loss: 89.9109 - mae: 7.5522 - val_loss: 121.8669 - val_mae: 8.8382
# Epoch 88/100
# 200/200 [==============================] - 1s 4ms/step - loss: 88.8619 - mae: 7.4982 - val_loss: 127.0702 - val_mae: 8.9799
# Epoch 89/100
# 200/200 [==============================] - 1s 4ms/step - loss: 89.7549 - mae: 7.5651 - val_loss: 122.3081 - val_mae: 8.7784
# Epoch 90/100
# 200/200 [==============================] - 1s 4ms/step - loss: 90.0759 - mae: 7.5422 - val_loss: 126.0797 - val_mae: 8.9363
# Epoch 91/100
# 200/200 [==============================] - 1s 4ms/step - loss: 88.9572 - mae: 7.5267 - val_loss: 123.8172 - val_mae: 8.8128
# Epoch 92/100
# 200/200 [==============================] - 1s 5ms/step - loss: 88.6103 - mae: 7.5027 - val_loss: 122.8267 - val_mae: 8.8639
# Epoch 93/100
# 200/200 [==============================] - 1s 4ms/step - loss: 88.4339 - mae: 7.4806 - val_loss: 122.6782 - val_mae: 8.8012
# Epoch 94/100
# 200/200 [==============================] - 1s 5ms/step - loss: 89.7662 - mae: 7.5709 - val_loss: 122.5778 - val_mae: 8.7922
# Epoch 95/100
# 200/200 [==============================] - 1s 4ms/step - loss: 88.9240 - mae: 7.5078 - val_loss: 126.7702 - val_mae: 8.9853
# Epoch 96/100
# 200/200 [==============================] - 1s 4ms/step - loss: 89.2749 - mae: 7.5293 - val_loss: 121.2592 - val_mae: 8.7662
# Epoch 97/100
# 200/200 [==============================] - 1s 5ms/step - loss: 89.0293 - mae: 7.5331 - val_loss: 120.5839 - val_mae: 8.7390
# Epoch 98/100
# 200/200 [==============================] - 1s 4ms/step - loss: 88.5011 - mae: 7.5051 - val_loss: 126.1577 - val_mae: 8.9225
# Epoch 99/100
# 200/200 [==============================] - 1s 4ms/step - loss: 88.5884 - mae: 7.5055 - val_loss: 121.5968 - val_mae: 8.7592
# Epoch 100/100
# 200/200 [==============================] - 1s 4ms/step - loss: 88.9824 - mae: 7.5038 - val_loss: 127.2115 - val_mae: 8.9845

# %%
hist.history['loss']
# Out:
# [34494.7890625,
#  12295.21875,
#  536.4822387695312,
#  300.85943603515625,
#  268.68438720703125,
#  252.3277130126953,
#  235.83319091796875,
#  221.31216430664062,
#  207.58978271484375,
#  193.71768188476562,
#  180.50071716308594,
#  168.59486389160156,
#  158.06393432617188,
#  149.77496337890625,
#  139.56619262695312,
#  132.91775512695312,
#  126.31829833984375,
#  123.31905364990234,
#  118.64659881591797,
#  115.56982421875,
#  113.45614624023438,
#  111.08373260498047,
#  108.87092590332031,
#  107.71931457519531,
#  107.35464477539062,
#  105.84386444091797,
#  105.01667785644531,
#  104.03713989257812,
#  104.06620025634766,
#  102.30169677734375,
#  101.65628051757812,
#  101.78434753417969,
#  100.4972152709961,
#  100.70817565917969,
#  100.27902221679688,
#  98.8448715209961,
#  98.55928802490234,
#  98.8320083618164,
#  98.81978607177734,
#  97.42340850830078,
#  96.43206024169922,
#  96.84123992919922,
#  97.64832305908203,
#  95.7149887084961,
#  96.30220794677734,
#  96.61405181884766,
#  95.55318450927734,
#  94.53643798828125,
#  95.65003967285156,
#  94.55030059814453,
#  94.7729263305664,
#  94.19593811035156,
#  94.66374969482422,
#  94.98086547851562,
#  94.24200439453125,
#  94.71688842773438,
#  93.23822021484375,
#  93.95001983642578,
#  92.86754608154297,
#  92.13533020019531,
#  92.74274444580078,
#  92.3121109008789,
#  93.27092742919922,
#  92.83474731445312,
#  91.0584487915039,
#  92.73628234863281,
#  91.9140853881836,
#  91.31078338623047,
#  92.81200408935547,
#  91.58946990966797,
#  91.58182525634766,
#  92.76112365722656,
#  90.95074462890625,
#  91.14153289794922,
#  90.9411849975586,
#  90.41535186767578,
#  90.63616180419922,
#  90.42023468017578,
#  90.62928771972656,
#  89.76949310302734,
#  90.3914566040039,
#  90.12727355957031,
#  88.7564468383789,
#  89.92420196533203,
#  90.43290710449219,
#  90.60469818115234,
#  89.91089630126953,
#  88.86193084716797,
#  89.7548828125,
#  90.07589721679688,
#  88.95719909667969,
#  88.6103286743164,
#  88.4338607788086,
#  89.76622009277344,
#  88.92404174804688,
#  89.27486419677734,
#  89.02925109863281,
#  88.50110626220703,
#  88.58841705322266,
#  88.98242950439453]

# %%
hist.history['val_loss']
# Out:
# [29896.8984375,
#  1133.8299560546875,
#  351.8643798828125,
#  293.51641845703125,
#  276.935791015625,
#  262.1380615234375,
#  258.9371643066406,
#  262.1614990234375,
#  225.54891967773438,
#  217.39193725585938,
#  207.14730834960938,
#  190.97093200683594,
#  182.498046875,
#  177.01744079589844,
#  165.7677764892578,
#  159.55104064941406,
#  152.59727478027344,
#  151.77406311035156,
#  147.2749786376953,
#  143.34017944335938,
#  139.68748474121094,
#  139.36480712890625,
#  136.32083129882812,
#  134.58935546875,
#  138.5493621826172,
#  135.11904907226562,
#  129.6862030029297,
#  134.41799926757812,
#  133.33970642089844,
#  129.03314208984375,
#  130.4051513671875,
#  130.28565979003906,
#  132.20863342285156,
#  131.0665283203125,
#  127.2928237915039,
#  126.4192123413086,
#  128.26683044433594,
#  126.48113250732422,
#  127.95318603515625,
#  125.29389953613281,
#  122.81983184814453,
#  128.8708953857422,
#  123.24356079101562,
#  125.04216766357422,
#  124.55390930175781,
#  123.58133697509766,
#  124.44277954101562,
#  123.91612243652344,
#  122.23750305175781,
#  128.13401794433594,
#  126.05316162109375,
#  128.21697998046875,
#  130.33035278320312,
#  123.81376647949219,
#  126.07421875,
#  124.70639038085938,
#  124.37018585205078,
#  125.99041748046875,
#  124.49728393554688,
#  123.23565673828125,
#  122.58174896240234,
#  125.20748901367188,
#  124.55928802490234,
#  126.86958312988281,
#  134.3427276611328,
#  120.79039001464844,
#  127.35189819335938,
#  127.32157135009766,
#  122.29618835449219,
#  120.92494201660156,
#  123.94140625,
#  120.87506103515625,
#  122.61203002929688,
#  123.84609985351562,
#  121.2071762084961,
#  123.45249938964844,
#  124.52399444580078,
#  121.84626770019531,
#  119.82392883300781,
#  125.65205383300781,
#  128.37750244140625,
#  123.55391693115234,
#  125.51115417480469,
#  123.54887390136719,
#  122.08995056152344,
#  125.3552017211914,
#  121.86691284179688,
#  127.07020568847656,
#  122.30805969238281,
#  126.07969665527344,
#  123.81724548339844,
#  122.82665252685547,
#  122.6782455444336,
#  122.57775115966797,
#  126.7702407836914,
#  121.25924682617188,
#  120.58391571044922,
#  126.15770721435547,
#  121.59678649902344,
#  127.21145629882812]

# %%
hist.history['mae']
# Out:
# [148.54055786132812,
#  76.0875473022461,
#  17.37251091003418,
#  13.609355926513672,
#  12.964073181152344,
#  12.539543151855469,
#  12.1658935546875,
#  11.784178733825684,
#  11.400723457336426,
#  11.00733757019043,
#  10.667677879333496,
#  10.331689834594727,
#  9.993122100830078,
#  9.728792190551758,
#  9.410487174987793,
#  9.18386459350586,
#  8.948526382446289,
#  8.86104965209961,
#  8.693342208862305,
#  8.581546783447266,
#  8.5031099319458,
#  8.413039207458496,
#  8.326767921447754,
#  8.277850151062012,
#  8.273147583007812,
#  8.248424530029297,
#  8.175622940063477,
#  8.136702537536621,
#  8.130934715270996,
#  8.0707426071167,
#  8.043042182922363,
#  8.04934310913086,
#  7.992119312286377,
#  7.995113372802734,
#  7.949621200561523,
#  7.921042442321777,
#  7.926450252532959,
#  7.9428019523620605,
#  7.929493427276611,
#  7.890434741973877,
#  7.837400913238525,
#  7.869729995727539,
#  7.919536590576172,
#  7.796542167663574,
#  7.843111515045166,
#  7.84619140625,
#  7.815863132476807,
#  7.769284725189209,
#  7.80377197265625,
#  7.7501044273376465,
#  7.78795051574707,
#  7.716592788696289,
#  7.746488094329834,
#  7.7596330642700195,
#  7.7617506980896,
#  7.789638042449951,
#  7.689233779907227,
#  7.722955226898193,
#  7.66916561126709,
#  7.665836811065674,
#  7.6713457107543945,
#  7.669287204742432,
#  7.697366714477539,
#  7.690478324890137,
#  7.622354507446289,
#  7.643679618835449,
#  7.621138095855713,
#  7.616764545440674,
#  7.659523963928223,
#  7.616984844207764,
#  7.641772270202637,
#  7.68458366394043,
#  7.6144843101501465,
#  7.5944695472717285,
#  7.602877140045166,
#  7.565237998962402,
#  7.58927059173584,
#  7.595744609832764,
#  7.603981971740723,
#  7.559673309326172,
#  7.579817295074463,
#  7.570317268371582,
#  7.487292289733887,
#  7.557361602783203,
#  7.558541297912598,
#  7.59025764465332,
#  7.552174091339111,
#  7.498240947723389,
#  7.565084457397461,
#  7.5422139167785645,
#  7.5267229080200195,
#  7.50271463394165,
#  7.480637073516846,
#  7.570920944213867,
#  7.507765293121338,
#  7.529318332672119,
#  7.533112049102783,
#  7.505058765411377,
#  7.505471229553223,
#  7.503756046295166]

# %%
hist.history['val_mae']
# Out:
# [136.7442169189453,
#  24.2437744140625,
#  14.71044635772705,
#  13.65334701538086,
#  13.22468376159668,
#  12.91495132446289,
#  12.871742248535156,
#  12.88601303100586,
#  12.044275283813477,
#  11.813767433166504,
#  11.539607048034668,
#  11.076824188232422,
#  10.757145881652832,
#  10.622252464294434,
#  10.297651290893555,
#  10.074564933776855,
#  9.845951080322266,
#  9.804025650024414,
#  9.702192306518555,
#  9.538963317871094,
#  9.392578125,
#  9.416494369506836,
#  9.305353164672852,
#  9.20940113067627,
#  9.392616271972656,
#  9.262190818786621,
#  9.036484718322754,
#  9.264245986938477,
#  9.183008193969727,
#  9.02475357055664,
#  9.039172172546387,
#  9.069018363952637,
#  9.135318756103516,
#  9.063882827758789,
#  8.978806495666504,
#  8.944899559020996,
#  8.947776794433594,
#  8.922871589660645,
#  9.027088165283203,
#  8.881638526916504,
#  8.791664123535156,
#  9.052644729614258,
#  8.791190147399902,
#  8.867188453674316,
#  8.842144012451172,
#  8.794166564941406,
#  8.82419490814209,
#  8.821343421936035,
#  8.773395538330078,
#  8.966628074645996,
#  8.917253494262695,
#  9.021498680114746,
#  9.039154052734375,
#  8.80877685546875,
#  8.92746639251709,
#  8.865073204040527,
#  8.85064697265625,
#  8.893136024475098,
#  8.846088409423828,
#  8.837078094482422,
#  8.794288635253906,
#  8.901586532592773,
#  8.897189140319824,
#  8.938584327697754,
#  9.255533218383789,
#  8.706870079040527,
#  8.970745086669922,
#  8.970458030700684,
#  8.832167625427246,
#  8.751241683959961,
#  8.842702865600586,
#  8.74600887298584,
#  8.815010070800781,
#  8.835121154785156,
#  8.755863189697266,
#  8.840298652648926,
#  8.903675079345703,
#  8.789875030517578,
#  8.733341217041016,
#  8.899430274963379,
#  9.029010772705078,
#  8.862465858459473,
#  8.907337188720703,
#  8.859880447387695,
#  8.792128562927246,
#  8.907583236694336,
#  8.838242530822754,
#  8.97994327545166,
#  8.778410911560059,
#  8.936309814453125,
#  8.812759399414062,
#  8.863946914672852,
#  8.801178932189941,
#  8.792204856872559,
#  8.985298156738281,
#  8.766197204589844,
#  8.738990783691406,
#  8.922540664672852,
#  8.759197235107422,
#  8.984487533569336]

# %% [markdown]
# ### Plot the learning curve

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 8))
plt.plot(hist.history['loss'], label='Training MSE')
plt.plot(hist.history['val_loss'], label='Valdiation MSE')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
plt.title('Learning Curve')
plt.show()

# %% [markdown]
# ### Predict values for train and test

# %%
ypred_tr = model.predict(xtrain)
ypred_ts = model.predict(xtest)
# Out:
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 0s 2ms/step

# %%
ypred_tr[0:5]
# Out:
# array([[   0.9669664],
#        [-166.0966   ],
#        [ -44.80416  ],
#        [ 305.45966  ],
#        [  40.855286 ]], dtype=float32)

# %%
ytrain.head()
# Out:
#                Y
# 9254  -12.438539
# 1561 -170.371791
# 1670  -45.466291
# 6087  301.429245
# 6669   44.699217

# %%
ypred_ts[0:5]
# Out:
# array([[ 164.10359 ],
#        [ 382.97705 ],
#        [-157.94252 ],
#        [ -26.024975],
#        [-107.03039 ]], dtype=float32)

# %%
ytest.head()
# Out:
#                Y
# 6252  160.109185
# 4684  379.549189
# 1731 -162.120660
# 4742  -32.375767
# 4521 -106.253689

# %% [markdown]
# ### Evaluate model based on different metrics

# %%
model.evaluate(xtrain, ytrain)
# Out:
# 250/250 [==============================] - 1s 3ms/step - loss: 96.9195 - mae: 7.8110
# [96.91947174072266, 7.811038494110107]

# %%
model.evaluate(xtest, ytest)
# Out:
# 63/63 [==============================] - 1s 5ms/step - loss: 133.1005 - mae: 9.1391
# [133.10049438476562, 9.139097213745117]

# %% [markdown]
# ### Check r2 score for train and test

# %%
from sklearn.metrics import r2_score
r2_score(ytrain, ypred_tr)
# Out:
# 0.9972629457461695

# %%
r2_score(ytest, ypred_ts)
# Out:
# 0.9962869695168881

# %% [markdown]
# ### Save the above model

# %%
model.save('RegressionModel.keras')

# %% [markdown]
# ### Load The model

# %%
from keras.models import load_model

# %%
aa = load_model('RegressionModel.keras')
aa

# %%
aa.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                992
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1665 (6.50 KB)
# Trainable params: 1665 (6.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
